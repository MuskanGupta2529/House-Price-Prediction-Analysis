# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Muskan\Downloads\ML Linear Regression Home Price Prediction & Analysis Project  Resource16932049360.txt")

# %%
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
data=data.drop(["Address","Date","Postcode","YearBuilt","Lattitude","Longtitude"],axis=1)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
data[data['Distance'].isnull()]
# Out:
#             Suburb  Rooms Type     Price Method SellerG  Distance  Bedroom2  \
# 29483  Fawkner Lot      3    h  616000.0     SP    Brad       NaN       NaN
#
#        Bathroom  Car  Landsize  BuildingArea CouncilArea Regionname  \
# 29483       NaN  NaN       NaN           NaN         NaN        NaN
#
#        Propertycount
# 29483            NaN

# %%
data.drop([29483],inplace=True)

# %%
data[data['Propertycount'].isnull()]
# Out:
#            Suburb  Rooms Type     Price Method SellerG  Distance  Bedroom2  \
# 18523   Footscray      2    u  710000.0      S     Jas       5.1       NaN
# 26888  Camberwell      2    h  825000.0     VB  Jellis       7.7       NaN
#
#        Bathroom  Car  Landsize  BuildingArea CouncilArea Regionname  \
# 18523       NaN  NaN       NaN           NaN         NaN        NaN
# 26888       NaN  NaN       NaN           NaN         NaN        NaN
#
#        Propertycount
# 18523            NaN
# 26888            NaN

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
data[['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']] = data[['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']].fillna(0)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
data[data['Regionname'].isnull()]
# Out:
#            Suburb  Rooms Type     Price Method SellerG  Distance  Bedroom2  \
# 18523   Footscray      2    u  710000.0      S     Jas       5.1       0.0
# 26888  Camberwell      2    h  825000.0     VB  Jellis       7.7       0.0
#
#        Bathroom  Car  Landsize  BuildingArea CouncilArea Regionname  \
# 18523       0.0  0.0       NaN           NaN         NaN        NaN
# 26888       0.0  0.0       NaN           NaN         NaN        NaN
#
#        Propertycount
# 18523            0.0
# 26888            0.0

# %%
data[(data['Rooms']==2)&(data['Type']=='u')|(data['Type']=='h')&(data['Method']=='S')]['Regionname'].value_counts()
# Out:
# Regionname
# Southern Metropolitan         6288
# Northern Metropolitan         5385
# Western Metropolitan          3569
# Eastern Metropolitan          2158
# South-Eastern Metropolitan     893
# Northern Victoria              109
# Eastern Victoria                97
# Western Victoria                71
# Name: count, dtype: int64

# %%
data['Landsize']=data['Landsize'].fillna(data.Landsize.mean())

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
data['BuildingArea']=data['BuildingArea'].fillna(data.BuildingArea.mean())

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# 5      Abbotsford      3    h   850000.0     PI         Biggin       2.5
# 6      Abbotsford      4    h  1600000.0     VB         Nelson       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
data['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
data=pd.get_dummies(data,drop_first=True)

# %%
data.astype(int)
# Out:
#        Rooms    Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1          2  1480000         2         2         1    1       202
# 2          2  1035000         2         2         1    0       156
# 4          3  1465000         2         3         2    0       134
# 5          3   850000         2         3         2    1        94
# 6          4  1600000         2         3         1    2       120
# ...      ...      ...       ...       ...       ...  ...       ...
# 34852      4  1480000         6         4         1    3       593
# 34853      2   888000         6         2         2    1        98
# 34854      2   705000         6         2         1    2       220
# 34855      3  1140000         6         0         0    0       593
# 34856      2  1020000         6         2         1    0       250
#
#        BuildingArea  Propertycount  Suburb_Aberfeldie  ...  \
# 1               160           4019                  0  ...
# ...

# %%
x=data.drop(columns='Price')

# %%
y=data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.68344493715678

# %%
model.score(x_test,y_test)
# Out:
# 0.6590586000135836

# %%
x_train.shape
# Out:
# (21795, 744)

# %%
x_test.shape
# Out:
# (5449, 744)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model=Ridge(alpha=50,max_iter=100)

# %%
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100)

# %%
ridge_model.score(x_train,y_train)
# Out:
# 0.6700726469247105

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.6462146396705563

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model=Lasso(alpha=50,max_iter=100)

# %%
lasso_model.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.454e+15, tolerance: 8.878e+11
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=50, max_iter=100)

# %%
lasso_model.score(x_train,y_train)
# Out:
# 0.6821183682143311

# %%
lasso_model.score(x_test,y_test)
# Out:
# 0.6494110097941648
